# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from qutip import *

# %%
K = np.complex(250,10)
k = np.complex(15,2)
E_p = 4*K

def create_cat_state():
    N = 10
    a = destroy(10)
    a_dag = create(10)
    
    r_not = (((4*E_p*E_p) - ((k*k)/4))/(4*K*K))**(1/4)
    theta_not = 0.5*np.arctan((k/(((16*E_p*E_p) - k*k)**(0.5))))
    a_not = r_not * np.exp(np.complex(0,theta_not))
    
    H_not = (-1)*K*a_dag*a_dag*a*a + (E_p*a_dag*a_dag + E_p.conjugate()*a*a)
    H_eff = H_not - np.complex(0,1)*(k*a_dag*a*0.5)
    D = displace(N,a_not)
    
    H_eff_prime = D.dag()*H_eff*D
    s = coherent(N,a_not)
    r = mesolve(H, psi0, tlist, [], [])
    return H_eff_prime

# %%
create_cat_state()
# Out:
# Quantum object: dims = [[10], [10]], shape = (10, 10), type = oper, isherm = False
# Qobj data =
# [[  3780.85370673-1.87777788e+02j   -596.04666871-3.05984264e+02j
#     -775.12410915-6.77303520e+01j   -284.66755657+6.29093330e+01j
#      526.33296522+4.77649517e+01j    574.77651529-1.66242616e+00j
#     -181.79105142-2.61273431e+01j   -415.93278891-2.66349688e+00j
#       80.40626921+1.29701897e+01j    160.51676167+6.32360723e-01j]
#  [  -595.4176806 -2.83459878e+01j  -1555.19713365-3.27855584e+02j
#    -3300.15858104-3.97656341e+02j   -350.63437971+1.43150591e+01j
#     1921.12672981+1.91637780e+02j   1827.17919565+4.61093219e+01j
#     -554.15225453-7.13047224e+01j  -1256.52911759-3.19776819e+01j
#      234.40750804+3.26140221e+01j    477.56658767+9.99080715e+00j]
#  [  -774.82287174-1.23287310e+01j  -3299.2613295 -7.92657645e+01j
#    -6320.55787599-3.90974054e+02j  -2474.67349849-3.19916487e+02j
#     4408.56025817+1.88120351e+02j   3660.65275843+2.41232973e+02j
#     -686.00511015-5.93389148e+01j  -2080.57263899-1.03140117e+02j
#      280.7865776 +2.38867688e+01j    763.11136666+3.22946577e+01j]
#  [  -284.91221424-1.95615675e+01j   -350.58743956-2.67902211e+01j
#    -2473.89452523-9.41363710e+01j  -5118.66010402-3.49982809e+02j
#     1349.18583868-1.76686649e+02j   5867.67810612+2.76768261e+02j
#      841.98166566+1.80456615e+02j  -1655.75422883-1.26713914e+02j
#     -165.73691693-5.76027648e+01j    567.44160416+3.95657446e+01j]
#  [   526.10604987-1.76120263e+01j   1920.29594224-4.44411474e+01j
#     4407.93933797-2.31000041e+01j   1349.67931109-8.56120359e+01j
#    -5645.35970177-3.11640503e+02j     18.49731077-9.14967682e+01j
#     5687.74258794+2.94499598e+02j   1316.98832451+1.30590320e+02j
#     -850.42635593-1.28745549e+02j   -301.20644057-1.91784063e+01j]
#  [   574.77042223+2.31014473e+00j   1826.93786428-1.40407713e+01j
#     3659.58114104-5.13667807e+01j   5866.7038926 -1.78540676e+01j
#       18.85772843-1.00078436e+02j  -8361.05727984-2.94927658e+02j
#      954.67956158-2.60215580e+01j   7559.63358025+2.89493796e+02j
#      508.79534439+9.85293171e+01j  -1080.33420853-9.25120003e+01j]
#  [  -181.63442372+1.22523546e+01j   -553.71827795+2.51711355e+01j
#     -685.58812321+3.92893313e+00j    841.27333069-5.49557934e+01j
#     5686.64172475-1.92605340e+00j    954.90868523-9.57660674e+01j
#    -8894.5286897 -2.76244336e+02j    504.44833158+5.73231306e+00j
#     7564.82036602+2.50814304e+02j    464.52524056+8.72065861e+01j]
#  [  -415.895556  -1.63579915e-01j  -1256.28829191+1.06439488e+01j
#    -2079.8919393 +3.07787956e+01j  -1654.92378568+1.63631189e+01j
#     1316.50579031-4.50962506e+01j   7558.40716951+3.64461948e+01j
#      504.59648448-8.44810121e+01j -11340.35323752-2.69515943e+02j
#      523.48549739+1.28477487e+01j   8049.86925558+1.61307020e+02j]
#  [    80.31046232-6.60505329e+00j    234.15084774-1.31259308e+01j
#      280.54482199-2.47065719e+00j   -165.43856806+2.58869899e+01j
#     -849.55528317+1.29958159e+01j    508.53587223-5.25567607e+01j
#     7563.59457276+7.49615838e+01j    523.57536872-6.06176523e+01j
#   -11880.26338042-2.28268015e+02j    335.89957592+1.00235611e+02j]
#  [   160.49882786+4.26703533e-01j    477.45919937-2.85623524e+00j
#      762.81857354-1.00630191e+01j    567.08444541-7.92655519e+00j
#     -301.1053703 +8.43419962e+00j  -1079.5815701 -7.49996197e+00j
#      464.37335885-6.02966061e+01j   8048.91293931+9.28506665e+01j
#      335.94073624-1.22113832e+02j  -4619.87630381-1.00313311e+02j]]

# %%
def plot_wigner(r):
    figure, axis = plt.subplots(1, 1, figsize=(8,8))
    x = np.linspace(-7.5,7.5,200)
    W = wigner(r, x, x)
    limit = abs(W).max()
    axis.contourf(x, x, W, 1000, norm=mpl.colors.Normalize(-limit,limit), cmap=mpl.cm.get_cmap('RdBu'))
    print(abs(W).max())
    return figure, axis

# %%
plot_wigner(create_cat_state())
# Out:
# 5506.266959255376
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f9140271358>)
